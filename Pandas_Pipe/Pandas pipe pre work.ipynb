# %% [markdown]
# # Pandas Pipe pre work

# %% [markdown]
# I downloaded a csv file about 80 cereal products with their dietary characteristics on <a href="https://perso.telecom-paristech.fr/eagan/class/igr204/datasets"> Project datasets.</a> The data is seperated by semicolons instead of commas. Pnadas handles it when you indicate what the seperator is by using `sep`.

# %%
import pandas as pd

df = pd.read_csv('Data/cereal.csv', sep=';')
df
# Out:
#                          name          mfr         type calories protein  fat  \
# 0                      String  Categorical  Categorical      Int     Int  Int
# 1                   100% Bran            N            C       70       4    1
# 2           100% Natural Bran            Q            C      120       3    5
# 3                    All-Bran            K            C       70       4    1
# 4   All-Bran with Extra Fiber            K            C       50       4    0
# ..                        ...          ...          ...      ...     ...  ...
# 73                    Triples            G            C      110       2    1
# 74                       Trix            G            C      110       1    1
# 75                 Wheat Chex            R            C      100       3    1
# 76                   Wheaties            G            C      100       3    1
# 77        Wheaties Honey Gold            G            C      110       2    1
#
#    sodium  fiber  carbo sugars potass vitamins shelf weight   cups     rating
# 0     Int  Float  Float    Int    Int      Int   Int  Float  Float      Float
# 1     130     10      5      6    280       25     3      1   0.33  68.402973
# 2      15      2      8      8    135        0     3      1      1  33.983679
# 3     260      9      7      5    320       25     3      1   0.33  59.425505
# 4     140     14      8      0    330       25     3      1    0.5  93.704912
# ..    ...    ...    ...    ...    ...      ...   ...    ...    ...        ...
# 73    250      0     21      3     60       25     3      1   0.75  39.106174
# 74    140      0     13     12     25       25     2      1      1  27.753301
# 75    230      3     17      3    115       25     1      1   0.67  49.787445
# 76    200      3     17      3    110       25     1      1      1  51.592193
# 77    200      1     16      8     60       25     1      1   0.75  36.187559
#
# [78 rows x 16 columns]

# %% [markdown]
# Here is the goal of this data analysis.
#
# 1. How many kinds of cereal each manufacturer has.
# 2. We want to find the best cereal for Sam. Sam's cereal should be protein >= 2, fat <=2, sugars <=7. Sam wants low calories and good rating as well.

# %% [markdown]
# Let's start. I do not want to change anything in the original data frame. So I will work with its copy. In this notebook, I will work with `pipe`s so that it is easy to find out what I have done in each code. This is also good when I want to redo something.

# %%
def copying(data):
    return data.copy()

# %% [markdown]
# The first row looks unnecessary. So we remove it.

# %%
def dropping(data):
    return data.drop([0])

# %% [markdown]
# Let's see if it works.

# %%
df.pipe(copying).pipe(dropping).head()
# Out:
#                         name mfr type calories protein fat sodium fiber carbo  \
# 1                  100% Bran   N    C       70       4   1    130    10     5
# 2          100% Natural Bran   Q    C      120       3   5     15     2     8
# 3                   All-Bran   K    C       70       4   1    260     9     7
# 4  All-Bran with Extra Fiber   K    C       50       4   0    140    14     8
# 5             Almond Delight   R    C      110       2   2    200     1    14
#
#   sugars potass vitamins shelf weight  cups     rating
# 1      6    280       25     3      1  0.33  68.402973
# 2      8    135        0     3      1     1  33.983679
# 3      5    320       25     3      1  0.33  59.425505
# 4      0    330       25     3      1   0.5  93.704912
# 5      8     -1       25     3      1  0.75  34.384843

# %% [markdown]
# What data type is each column?

# %%
df.dtypes
# Out:
# name        object
# mfr         object
# type        object
# calories    object
# protein     object
# fat         object
# sodium      object
# fiber       object
# carbo       object
# sugars      object
# potass      object
# vitamins    object
# shelf       object
# weight      object
# cups        object
# rating      object
# dtype: object

# %% [markdown]
# We want to change all the columns except first three into numbers. What is the size of this data frame and how many columns are there?

# %%
df.shape
# Out:
# (78, 16)

# %% [markdown]
# Let's convert last 13 columns into numbers. Maybe Pandas can magically do it?

# %%
def data_types(data):
    return data.convert_dtypes().dtypes   
 
df.pipe(copying).pipe(dropping).pipe(data_types)
# Out:
# name        string
# mfr         string
# type        string
# calories    string
# protein     string
# fat         string
# sodium      string
# fiber       string
# carbo       string
# sugars      string
# potass      string
# vitamins    string
# shelf       string
# weight      string
# cups        string
# rating      string
# dtype: object

# %% [markdown]
# No. Pandas can't do it.
# We will make a list of column names and then use `apply(pd.to_numeric)`. Is there a better way to convert 13 columns into numbers at once?

# %%
cols = list(df.pipe(copying).pipe(dropping).columns)[3:15]
print(cols)
# Out:
# ['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups']

# %% [markdown]
# OK. We change all columns in cols into numbers.

# %%
def new_data_types(data):
    data[cols] = data[cols].apply(pd.to_numeric)
    return data   

df.pipe(copying).pipe(dropping).pipe(new_data_types).dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating       object
# dtype: object

# %% [markdown]
# ### 1. We want to know how many products each manufacturer has.

# %%
def mfr_group(data):
    gdata = data.groupby(['mfr'])
    return data['mfr'].value_counts()
 
df.pipe(copying).pipe(dropping).pipe(mfr_group)
# Out:
# K    23
# G    22
# P     9
# R     8
# Q     8
# N     6
# A     1
# Name: mfr, dtype: int64

# %% [markdown]
# When we are only interested in mfr which has more than 10 products, we can use `groupby` and `agg`.

# %%
def removing_low_mfr(data, min_products = 10):
    mfr_no_products = (data
                 .groupby('mfr')
                 .agg(n=('name', 'count'))
                 .loc[lambda d: d['n'] >= min_products]
                 .index)
    return (data
            .loc[lambda d: d['mfr'].isin(mfr_no_products)])

df.pipe(copying).pipe(dropping).pipe(removing_low_mfr)
# Out:
#                            name mfr type calories protein fat sodium fiber  \
# 3                      All-Bran   K    C       70       4   1    260     9
# 4     All-Bran with Extra Fiber   K    C       50       4   0    140    14
# 6       Apple Cinnamon Cheerios   G    C      110       2   2    180   1.5
# 7                   Apple Jacks   K    C      110       2   0    125     1
# 8                       Basic 4   G    C      130       3   2    210     2
# 12                     Cheerios   G    C      110       6   2    290     2
# 13        Cinnamon Toast Crunch   G    C      120       1   3    210     0
# 14                     Clusters   G    C      110       3   2    140     2
# 15                  Cocoa Puffs   G    C      110       1   1    180     0
# 17                  Corn Flakes   K    C      100       2   0    290     1
# 18                    Corn Pops   K    C      110       1   0     90     1
# 19                Count Chocula   G    C      110       1   1    180     0
# 20           Cracklin' Oat Bran   K    C      110       3   3    140     4
# 22                      Crispix   K    C      110       2   0    220     1
# 23       Crispy Wheat & Raisins   G    C      100       2   1    140     2
# 25                  Froot Loops   K    C      110       2   1    125     1
# 26               Frosted Flakes   K    C      110       1   0    200     1
# 27          Frosted Mini-Wheats   K    C      100       3   0      0     3
# 29                Fruitful Bran   K    C      120       3   0    240     5
# 32               Golden Grahams   G    C      110       1   1    280     0
# 37           Honey Nut Cheerios   G    C      110       3   1    250   1.5
# 39  Just Right Crunchy  Nuggets   K    C      110       2   1    170     1
# 40       Just Right Fruit & Nut   K    C      140       3   1    170     2
# 41                          Kix   G    C      110       2   1    260     0
# 43                 Lucky Charms   G    C      110       2   1    180     0
# 47         Mueslix Crispy Blend   K    C      160       3   2    150     3
# 48         Multi-Grain Cheerios   G    C      100       2   1    220     2
# 49             Nut&Honey Crunch   K    C      120       2   1    190     0
# 50    Nutri-Grain Almond-Raisin   K    C      140       3   2    220     3
# 51            Nutri-grain Wheat   K    C       90       3   0    170     3
# 52         Oatmeal Raisin Crisp   G    C      130       3   2    170   1.5
# 54                   Product 19   K    C      100       3   0    320     1
# 59                  Raisin Bran   K    C      120       3   1    210     5
# 60              Raisin Nut Bran   G    C      100       3   2    140   2.5
# 61               Raisin Squares   K    C       90       2   0      0     2
# 63                Rice Krispies   K    C      110       2   0    290     0
# 67                       Smacks   K    C      110       2   1     70     1
# 68                    Special K   K    C      110       6   0    230     1
# 70            Total Corn Flakes   G    C      110       2   1    200     0
# 71            Total Raisin Bran   G    C      140       3   1    190     4
# 72            Total Whole Grain   G    C      100       3   1    200     3
# 73                      Triples   G    C      110       2   1    250     0
# 74                         Trix   G    C      110       1   1    140     0
# 76                     Wheaties   G    C      100       3   1    200     3
# 77          Wheaties Honey Gold   G    C      110       2   1    200     1
#
#    carbo sugars potass vitamins shelf weight  cups     rating
# 3      7      5    320       25     3      1  0.33  59.425505
# 4      8      0    330       25     3      1   0.5  93.704912
# 6   10.5     10     70       25     1      1  0.75  29.509541
# 7     11     14     30       25     2      1     1  33.174094
# 8     18      8    100       25     3   1.33  0.75  37.038562
# 12    17      1    105       25     1      1  1.25  50.764999
# 13    13      9     45       25     2      1  0.75  19.823573
# 14    13      7    105       25     3      1   0.5  40.400208
# 15    12     13     55       25     2      1     1  22.736446
# 17    21      2     35       25     1      1     1  45.863324
# 18    13     12     20       25     2      1     1  35.782791
# 19    12     13     65       25     2      1     1  22.396513
# 20    10      7    160       25     3      1   0.5  40.448772
# 22    21      3     30       25     3      1     1  46.895644
# 23    11     10    120       25     3      1  0.75  36.176196
# 25    11     13     30       25     2      1     1  32.207582
# 26    14     11     25       25     1      1  0.75  31.435973
# 27    14      7    100       25     2      1   0.8  58.345141
# 29    14     12    190       25     3   1.33  0.67  41.015492
# 32    15      9     45       25     2      1  0.75  23.804043
# 37  11.5     10     90       25     1      1  0.75  31.072217
# 39    17      6     60      100     3      1     1  36.523683
# 40    20      9     95      100     3    1.3  0.75  36.471512
# 41    21      3     40       25     2      1   1.5  39.241114
# 43    12     12     55       25     2      1     1  26.734515
# 47    17     13    160       25     3    1.5  0.67  30.313351
# 48    15      6     90       25     1      1     1  40.105965
# 49    15      9     40       25     2      1  0.67  29.924285
# 50    21      7    130       25     3   1.33  0.67  40.692320
# 51    18      2     90       25     3      1     1  59.642837
# 52  13.5     10    120       25     3   1.25   0.5  30.450843
# 54    20      3     45      100     3      1     1  41.503540
# 59    14     12    240       25     2   1.33  0.75  39.259197
# 60  10.5      8    140       25     3      1   0.5  39.703400
# 61    15      6    110       25     3      1   0.5  55.333142
# 63    22      3     35       25     1      1     1  40.560159
# 67     9     15     40       25     2      1  0.75  31.230054
# 68    16      3     55       25     1      1     1  53.131324
# 70    21      3     35      100     3      1     1  38.839746
# 71    15     14    230      100     3    1.5     1  28.592785
# 72    16      3    110      100     3      1     1  46.658844
# 73    21      3     60       25     3      1  0.75  39.106174
# 74    13     12     25       25     2      1     1  27.753301
# 76    17      3    110       25     1      1     1  51.592193
# 77    16      8     60       25     1      1  0.75  36.187559

# %% [markdown]
# We can also make a multiindex. I have no idea what type is in the column names. Anyway, let mfr, type and name be indexes.

# %%
def indexing(data):
    return data.set_index(['type', 'mfr', 'name']).sort_index()

# %% [markdown]
# Let's have a look!

# %%
clean_df = df.pipe(copying).pipe(dropping).pipe(indexing)
clean_df
# Out:
#                                  calories protein fat sodium fiber carbo  \
# type mfr name
# C    G   Apple Cinnamon Cheerios      110       2   2    180   1.5  10.5
#          Basic 4                      130       3   2    210     2    18
#          Cheerios                     110       6   2    290     2    17
#          Cinnamon Toast Crunch        120       1   3    210     0    13
#          Clusters                     110       3   2    140     2    13
# ...                                   ...     ...  ..    ...   ...   ...
#      R   Rice Chex                    110       1   0    240     0    23
#          Wheat Chex                   100       3   1    230     3    17
# H    A   Maypo                        100       4   1      0     0    16
#      N   Cream of Wheat (Quick)       100       3   0     80     1    21
#      Q   Quaker Oatmeal               100       5   2      0   2.7    -1
#
#                                  sugars potass vitamins shelf weight  cups  \
# type mfr name
# C    G   Apple Cinnamon Cheerios     10     70       25     1      1  0.75
#          Basic 4                      8    100       25     3   1.33  0.75
#          Cheerios                     1    105       25     1      1  1.25
#          Cinnamon Toast Crunch        9     45       25     2      1  0.75
#          Clusters                     7    105       25     3      1   0.5
# ...                                 ...    ...      ...   ...    ...   ...
#      R   Rice Chex                    2     30       25     1      1  1.13
#          Wheat Chex                   3    115       25     1      1  0.67
# H    A   Maypo                        3     95       25     2      1     1
#      N   Cream of Wheat (Quick)       0     -1        0     2      1     1
#      Q   Quaker Oatmeal              -1    110        0     1      1  0.67
#
#                                      rating
# type mfr name
# C    G   Apple Cinnamon Cheerios  29.509541
#          Basic 4                  37.038562
#          Cheerios                 50.764999
#          Cinnamon Toast Crunch    19.823573
#          Clusters                 40.400208
# ...                                     ...
#      R   Rice Chex                41.998933
#          Wheat Chex               49.787445
# H    A   Maypo                    54.850917
#      N   Cream of Wheat (Quick)   64.533816
#      Q   Quaker Oatmeal           50.828392
#
# [77 rows x 13 columns]

# %% [markdown]
# If we are only interested in manufacturer G and K, then we can use `IndexSlice`.

# %%
clean_df.loc[pd.IndexSlice[:, ['G', 'K']], :]
# Out:
#                                      calories protein fat sodium fiber carbo  \
# type mfr name
# C    G   Apple Cinnamon Cheerios          110       2   2    180   1.5  10.5
#          Basic 4                          130       3   2    210     2    18
#          Cheerios                         110       6   2    290     2    17
#          Cinnamon Toast Crunch            120       1   3    210     0    13
#          Clusters                         110       3   2    140     2    13
#          Cocoa Puffs                      110       1   1    180     0    12
#          Count Chocula                    110       1   1    180     0    12
#          Crispy Wheat & Raisins           100       2   1    140     2    11
#          Golden Grahams                   110       1   1    280     0    15
#          Honey Nut Cheerios               110       3   1    250   1.5  11.5
#          Kix                              110       2   1    260     0    21
#          Lucky Charms                     110       2   1    180     0    12
#          Multi-Grain Cheerios             100       2   1    220     2    15
#          Oatmeal Raisin Crisp             130       3   2    170   1.5  13.5
#          Raisin Nut Bran                  100       3   2    140   2.5  10.5
#          Total Corn Flakes                110       2   1    200     0    21
#          Total Raisin Bran                140       3   1    190     4    15
#          Total Whole Grain                100       3   1    200     3    16
#          Triples                          110       2   1    250     0    21
#          Trix                             110       1   1    140     0    13
#          Wheaties                         100       3   1    200     3    17
#          Wheaties Honey Gold              110       2   1    200     1    16
#      K   All-Bran                          70       4   1    260     9     7
#          All-Bran with Extra Fiber         50       4   0    140    14     8
#          Apple Jacks                      110       2   0    125     1    11
#          Corn Flakes                      100       2   0    290     1    21
#          Corn Pops                        110       1   0     90     1    13
#          Cracklin' Oat Bran               110       3   3    140     4    10
#          Crispix                          110       2   0    220     1    21
#          Froot Loops                      110       2   1    125     1    11
#          Frosted Flakes                   110       1   0    200     1    14
#          Frosted Mini-Wheats              100       3   0      0     3    14
#          Fruitful Bran                    120       3   0    240     5    14
#          Just Right Crunchy  Nuggets      110       2   1    170     1    17
#          Just Right Fruit & Nut           140       3   1    170     2    20
#          Mueslix Crispy Blend             160       3   2    150     3    17
#          Nut&Honey Crunch                 120       2   1    190     0    15
#          Nutri-Grain Almond-Raisin        140       3   2    220     3    21
#          Nutri-grain Wheat                 90       3   0    170     3    18
#          Product 19                       100       3   0    320     1    20
#          Raisin Bran                      120       3   1    210     5    14
#          Raisin Squares                    90       2   0      0     2    15
#          Rice Krispies                    110       2   0    290     0    22
#          Smacks                           110       2   1     70     1     9
#          Special K                        110       6   0    230     1    16
#
#                                      sugars potass vitamins shelf weight  \
# type mfr name
# C    G   Apple Cinnamon Cheerios         10     70       25     1      1
#          Basic 4                          8    100       25     3   1.33
#          Cheerios                         1    105       25     1      1
#          Cinnamon Toast Crunch            9     45       25     2      1
#          Clusters                         7    105       25     3      1
#          Cocoa Puffs                     13     55       25     2      1
#          Count Chocula                   13     65       25     2      1
#          Crispy Wheat & Raisins          10    120       25     3      1
#          Golden Grahams                   9     45       25     2      1
#          Honey Nut Cheerios              10     90       25     1      1
#          Kix                              3     40       25     2      1
#          Lucky Charms                    12     55       25     2      1
#          Multi-Grain Cheerios             6     90       25     1      1
#          Oatmeal Raisin Crisp            10    120       25     3   1.25
#          Raisin Nut Bran                  8    140       25     3      1
#          Total Corn Flakes                3     35      100     3      1
#          Total Raisin Bran               14    230      100     3    1.5
#          Total Whole Grain                3    110      100     3      1
#          Triples                          3     60       25     3      1
#          Trix                            12     25       25     2      1
#          Wheaties                         3    110       25     1      1
#          Wheaties Honey Gold              8     60       25     1      1
#      K   All-Bran                         5    320       25     3      1
#          All-Bran with Extra Fiber        0    330       25     3      1
#          Apple Jacks                     14     30       25     2      1
#          Corn Flakes                      2     35       25     1      1
#          Corn Pops                       12     20       25     2      1
#          Cracklin' Oat Bran               7    160       25     3      1
#          Crispix                          3     30       25     3      1
#          Froot Loops                     13     30       25     2      1
#          Frosted Flakes                  11     25       25     1      1
#          Frosted Mini-Wheats              7    100       25     2      1
#          Fruitful Bran                   12    190       25     3   1.33
#          Just Right Crunchy  Nuggets      6     60      100     3      1
#          Just Right Fruit & Nut           9     95      100     3    1.3
#          Mueslix Crispy Blend            13    160       25     3    1.5
#          Nut&Honey Crunch                 9     40       25     2      1
#          Nutri-Grain Almond-Raisin        7    130       25     3   1.33
#          Nutri-grain Wheat                2     90       25     3      1
#          Product 19                       3     45      100     3      1
#          Raisin Bran                     12    240       25     2   1.33
#          Raisin Squares                   6    110       25     3      1
#          Rice Krispies                    3     35       25     1      1
#          Smacks                          15     40       25     2      1
#          Special K                        3     55       25     1      1
#
#                                       cups     rating
# type mfr name
# C    G   Apple Cinnamon Cheerios      0.75  29.509541
#          Basic 4                      0.75  37.038562
#          Cheerios                     1.25  50.764999
#          Cinnamon Toast Crunch        0.75  19.823573
#          Clusters                      0.5  40.400208
#          Cocoa Puffs                     1  22.736446
#          Count Chocula                   1  22.396513
#          Crispy Wheat & Raisins       0.75  36.176196
#          Golden Grahams               0.75  23.804043
#          Honey Nut Cheerios           0.75  31.072217
#          Kix                           1.5  39.241114
#          Lucky Charms                    1  26.734515
#          Multi-Grain Cheerios            1  40.105965
#          Oatmeal Raisin Crisp          0.5  30.450843
#          Raisin Nut Bran               0.5  39.703400
#          Total Corn Flakes               1  38.839746
#          Total Raisin Bran               1  28.592785
#          Total Whole Grain               1  46.658844
#          Triples                      0.75  39.106174
#          Trix                            1  27.753301
#          Wheaties                        1  51.592193
#          Wheaties Honey Gold          0.75  36.187559
#      K   All-Bran                     0.33  59.425505
#          All-Bran with Extra Fiber     0.5  93.704912
#          Apple Jacks                     1  33.174094
#          Corn Flakes                     1  45.863324
#          Corn Pops                       1  35.782791
#          Cracklin' Oat Bran            0.5  40.448772
#          Crispix                         1  46.895644
#          Froot Loops                     1  32.207582
#          Frosted Flakes               0.75  31.435973
#          Frosted Mini-Wheats           0.8  58.345141
#          Fruitful Bran                0.67  41.015492
#          Just Right Crunchy  Nuggets     1  36.523683
#          Just Right Fruit & Nut       0.75  36.471512
#          Mueslix Crispy Blend         0.67  30.313351
#          Nut&Honey Crunch             0.67  29.924285
#          Nutri-Grain Almond-Raisin    0.67  40.692320
#          Nutri-grain Wheat               1  59.642837
#          Product 19                      1  41.503540
#          Raisin Bran                  0.75  39.259197
#          Raisin Squares                0.5  55.333142
#          Rice Krispies                   1  40.560159
#          Smacks                       0.75  31.230054
#          Special K                       1  53.131324

# %% [markdown]
# ### 2. We want to find the best cereal for Sam.
# Let's find cereals which have protein >= 2, fat <=2, sugars <=7.

# %%
def nutrition_sieve(data, min_protein = 2, max_fat=2, max_sugars=7):
    mask = (data['protein'] >=min_protein) & (data['fat'] <= max_fat) & (data['sugars'] <= max_sugars)
    return data[mask]
df.pipe(copying).pipe(dropping).pipe(new_data_types).pipe(indexing).pipe(nutrition_sieve)
# Out:
#                                       calories  protein  fat  sodium  fiber  \
# type mfr name
# C    G   Cheerios                          110        6    2     290    2.0
#          Clusters                          110        3    2     140    2.0
#          Kix                               110        2    1     260    0.0
#          Multi-Grain Cheerios              100        2    1     220    2.0
#          Total Corn Flakes                 110        2    1     200    0.0
#          Total Whole Grain                 100        3    1     200    3.0
#          Triples                           110        2    1     250    0.0
#          Wheaties                          100        3    1     200    3.0
#      K   All-Bran                           70        4    1     260    9.0
#          All-Bran with Extra Fiber          50        4    0     140   14.0
#          Corn Flakes                       100        2    0     290    1.0
#          Crispix                           110        2    0     220    1.0
#          Frosted Mini-Wheats               100        3    0       0    3.0
#          Just Right Crunchy  Nuggets       110        2    1     170    1.0
#          Nutri-Grain Almond-Raisin         140        3    2     220    3.0
#          Nutri-grain Wheat                  90        3    0     170    3.0
#          Product 19                        100        3    0     320    1.0
#          Raisin Squares                     90        2    0       0    2.0
#          Rice Krispies                     110        2    0     290    0.0
#          Special K                         110        6    0     230    1.0
#      N   100% Bran                          70        4    1     130   10.0
#          Shredded Wheat                     80        2    0       0    3.0
#          Shredded Wheat 'n'Bran             90        3    0       0    4.0
#          Shredded Wheat spoon size          90        3    0       0    3.0
#          Strawberry Fruit Wheats            90        2    0      15    3.0
#      P   Bran Flakes                        90        3    0     210    5.0
#          Grape Nuts Flakes                 100        3    1     140    3.0
#          Grape-Nuts                        110        3    0     170    3.0
#      Q   Life                              100        4    2     150    2.0
#          Puffed Wheat                       50        2    0       0    1.0
#          Quaker Oat Squares                100        4    1     135    2.0
#      R   Bran Chex                          90        2    1     200    4.0
#          Corn Chex                         110        2    0     280    0.0
#          Double Chex                       100        2    0     190    1.0
#          Wheat Chex                        100        3    1     230    3.0
# H    A   Maypo                             100        4    1       0    0.0
#      N   Cream of Wheat (Quick)            100        3    0      80    1.0
#      Q   Quaker Oatmeal                    100        5    2       0    2.7
#
#                                       carbo  sugars  potass  vitamins  shelf  \
# type mfr name
# C    G   Cheerios                      17.0       1     105        25      1
#          Clusters                      13.0       7     105        25      3
#          Kix                           21.0       3      40        25      2
#          Multi-Grain Cheerios          15.0       6      90        25      1
#          Total Corn Flakes             21.0       3      35       100      3
#          Total Whole Grain             16.0       3     110       100      3
#          Triples                       21.0       3      60        25      3
#          Wheaties                      17.0       3     110        25      1
#      K   All-Bran                       7.0       5     320        25      3
#          All-Bran with Extra Fiber      8.0       0     330        25      3
#          Corn Flakes                   21.0       2      35        25      1
#          Crispix                       21.0       3      30        25      3
#          Frosted Mini-Wheats           14.0       7     100        25      2
#          Just Right Crunchy  Nuggets   17.0       6      60       100      3
#          Nutri-Grain Almond-Raisin     21.0       7     130        25      3
#          Nutri-grain Wheat             18.0       2      90        25      3
#          Product 19                    20.0       3      45       100      3
#          Raisin Squares                15.0       6     110        25      3
#          Rice Krispies                 22.0       3      35        25      1
#          Special K                     16.0       3      55        25      1
#      N   100% Bran                      5.0       6     280        25      3
#          Shredded Wheat                16.0       0      95         0      1
#          Shredded Wheat 'n'Bran        19.0       0     140         0      1
#          Shredded Wheat spoon size     20.0       0     120         0      1
#          Strawberry Fruit Wheats       15.0       5      90        25      2
#      P   Bran Flakes                   13.0       5     190        25      3
#          Grape Nuts Flakes             15.0       5      85        25      3
#          Grape-Nuts                    17.0       3      90        25      3
#      Q   Life                          12.0       6      95        25      2
#          Puffed Wheat                  10.0       0      50         0      3
#          Quaker Oat Squares            14.0       6     110        25      3
#      R   Bran Chex                     15.0       6     125        25      1
#          Corn Chex                     22.0       3      25        25      1
#          Double Chex                   18.0       5      80        25      3
#          Wheat Chex                    17.0       3     115        25      1
# H    A   Maypo                         16.0       3      95        25      2
#      N   Cream of Wheat (Quick)        21.0       0      -1         0      2
#      Q   Quaker Oatmeal                -1.0      -1     110         0      1
#
#                                       weight  cups     rating
# type mfr name
# C    G   Cheerios                       1.00  1.25  50.764999
#          Clusters                       1.00  0.50  40.400208
#          Kix                            1.00  1.50  39.241114
#          Multi-Grain Cheerios           1.00  1.00  40.105965
#          Total Corn Flakes              1.00  1.00  38.839746
#          Total Whole Grain              1.00  1.00  46.658844
#          Triples                        1.00  0.75  39.106174
#          Wheaties                       1.00  1.00  51.592193
#      K   All-Bran                       1.00  0.33  59.425505
#          All-Bran with Extra Fiber      1.00  0.50  93.704912
#          Corn Flakes                    1.00  1.00  45.863324
#          Crispix                        1.00  1.00  46.895644
#          Frosted Mini-Wheats            1.00  0.80  58.345141
#          Just Right Crunchy  Nuggets    1.00  1.00  36.523683
#          Nutri-Grain Almond-Raisin      1.33  0.67  40.692320
#          Nutri-grain Wheat              1.00  1.00  59.642837
#          Product 19                     1.00  1.00  41.503540
#          Raisin Squares                 1.00  0.50  55.333142
#          Rice Krispies                  1.00  1.00  40.560159
#          Special K                      1.00  1.00  53.131324
#      N   100% Bran                      1.00  0.33  68.402973
#          Shredded Wheat                 0.83  1.00  68.235885
#          Shredded Wheat 'n'Bran         1.00  0.67  74.472949
#          Shredded Wheat spoon size      1.00  0.67  72.801787
#          Strawberry Fruit Wheats        1.00  1.00  59.363993
#      P   Bran Flakes                    1.00  0.67  53.313813
#          Grape Nuts Flakes              1.00  0.88  52.076897
#          Grape-Nuts                     1.00  0.25  53.371007
#      Q   Life                           1.00  0.67  45.328074
#          Puffed Wheat                   0.50  1.00  63.005645
#          Quaker Oat Squares             1.00  0.50  49.511874
#      R   Bran Chex                      1.00  0.67  49.120253
#          Corn Chex                      1.00  1.00  41.445019
#          Double Chex                    1.00  0.75  44.330856
#          Wheat Chex                     1.00  0.67  49.787445
# H    A   Maypo                          1.00  1.00  54.850917
#      N   Cream of Wheat (Quick)         1.00  1.00  64.533816
#      Q   Quaker Oatmeal                 1.00  0.67  50.828392

# %% [markdown]
# We want to find the best cereal forSam wants low calories and good rating as well.

# %%
def sorting(data):
    data1 = data.sort_values(['rating'], ascending=False)
    return data1.sort_values(['calories'])
df.pipe(copying).pipe(dropping).pipe(new_data_types).pipe(indexing).pipe(nutrition_sieve).pipe(sorting)
# Out:
#                                       calories  protein  fat  sodium  fiber  \
# type mfr name
# C    K   All-Bran with Extra Fiber          50        4    0     140   14.0
#      Q   Puffed Wheat                       50        2    0       0    1.0
#      N   100% Bran                          70        4    1     130   10.0
#      K   All-Bran                           70        4    1     260    9.0
#      N   Shredded Wheat                     80        2    0       0    3.0
#      R   Bran Chex                          90        2    1     200    4.0
#      P   Bran Flakes                        90        3    0     210    5.0
#      K   Raisin Squares                     90        2    0       0    2.0
#      N   Strawberry Fruit Wheats            90        2    0      15    3.0
#          Shredded Wheat spoon size          90        3    0       0    3.0
#          Shredded Wheat 'n'Bran             90        3    0       0    4.0
#      K   Nutri-grain Wheat                  90        3    0     170    3.0
#      Q   Quaker Oat Squares                100        4    1     135    2.0
#      K   Product 19                        100        3    0     320    1.0
#      G   Multi-Grain Cheerios              100        2    1     220    2.0
#      R   Double Chex                       100        2    0     190    1.0
#      Q   Life                              100        4    2     150    2.0
#      K   Corn Flakes                       100        2    0     290    1.0
#      G   Total Whole Grain                 100        3    1     200    3.0
#      R   Wheat Chex                        100        3    1     230    3.0
# H    Q   Quaker Oatmeal                    100        5    2       0    2.7
# C    G   Wheaties                          100        3    1     200    3.0
#      P   Grape Nuts Flakes                 100        3    1     140    3.0
# H    N   Cream of Wheat (Quick)            100        3    0      80    1.0
#      A   Maypo                             100        4    1       0    0.0
# C    K   Frosted Mini-Wheats               100        3    0       0    3.0
#      G   Total Corn Flakes                 110        2    1     200    0.0
#          Triples                           110        2    1     250    0.0
#          Kix                               110        2    1     260    0.0
#          Clusters                          110        3    2     140    2.0
#      K   Rice Krispies                     110        2    0     290    0.0
#      R   Corn Chex                         110        2    0     280    0.0
#      G   Cheerios                          110        6    2     290    2.0
#      P   Grape-Nuts                        110        3    0     170    3.0
#      K   Special K                         110        6    0     230    1.0
#          Crispix                           110        2    0     220    1.0
#          Just Right Crunchy  Nuggets       110        2    1     170    1.0
#          Nutri-Grain Almond-Raisin         140        3    2     220    3.0
#
#                                       carbo  sugars  potass  vitamins  shelf  \
# type mfr name
# C    K   All-Bran with Extra Fiber      8.0       0     330        25      3
#      Q   Puffed Wheat                  10.0       0      50         0      3
#      N   100% Bran                      5.0       6     280        25      3
#      K   All-Bran                       7.0       5     320        25      3
#      N   Shredded Wheat                16.0       0      95         0      1
#      R   Bran Chex                     15.0       6     125        25      1
#      P   Bran Flakes                   13.0       5     190        25      3
#      K   Raisin Squares                15.0       6     110        25      3
#      N   Strawberry Fruit Wheats       15.0       5      90        25      2
#          Shredded Wheat spoon size     20.0       0     120         0      1
#          Shredded Wheat 'n'Bran        19.0       0     140         0      1
#      K   Nutri-grain Wheat             18.0       2      90        25      3
#      Q   Quaker Oat Squares            14.0       6     110        25      3
#      K   Product 19                    20.0       3      45       100      3
#      G   Multi-Grain Cheerios          15.0       6      90        25      1
#      R   Double Chex                   18.0       5      80        25      3
#      Q   Life                          12.0       6      95        25      2
#      K   Corn Flakes                   21.0       2      35        25      1
#      G   Total Whole Grain             16.0       3     110       100      3
#      R   Wheat Chex                    17.0       3     115        25      1
# H    Q   Quaker Oatmeal                -1.0      -1     110         0      1
# C    G   Wheaties                      17.0       3     110        25      1
#      P   Grape Nuts Flakes             15.0       5      85        25      3
# H    N   Cream of Wheat (Quick)        21.0       0      -1         0      2
#      A   Maypo                         16.0       3      95        25      2
# C    K   Frosted Mini-Wheats           14.0       7     100        25      2
#      G   Total Corn Flakes             21.0       3      35       100      3
#          Triples                       21.0       3      60        25      3
#          Kix                           21.0       3      40        25      2
#          Clusters                      13.0       7     105        25      3
#      K   Rice Krispies                 22.0       3      35        25      1
#      R   Corn Chex                     22.0       3      25        25      1
#      G   Cheerios                      17.0       1     105        25      1
#      P   Grape-Nuts                    17.0       3      90        25      3
#      K   Special K                     16.0       3      55        25      1
#          Crispix                       21.0       3      30        25      3
#          Just Right Crunchy  Nuggets   17.0       6      60       100      3
#          Nutri-Grain Almond-Raisin     21.0       7     130        25      3
#
#                                       weight  cups     rating
# type mfr name
# C    K   All-Bran with Extra Fiber      1.00  0.50  93.704912
#      Q   Puffed Wheat                   0.50  1.00  63.005645
#      N   100% Bran                      1.00  0.33  68.402973
#      K   All-Bran                       1.00  0.33  59.425505
#      N   Shredded Wheat                 0.83  1.00  68.235885
#      R   Bran Chex                      1.00  0.67  49.120253
#      P   Bran Flakes                    1.00  0.67  53.313813
#      K   Raisin Squares                 1.00  0.50  55.333142
#      N   Strawberry Fruit Wheats        1.00  1.00  59.363993
#          Shredded Wheat spoon size      1.00  0.67  72.801787
#          Shredded Wheat 'n'Bran         1.00  0.67  74.472949
#      K   Nutri-grain Wheat              1.00  1.00  59.642837
#      Q   Quaker Oat Squares             1.00  0.50  49.511874
#      K   Product 19                     1.00  1.00  41.503540
#      G   Multi-Grain Cheerios           1.00  1.00  40.105965
#      R   Double Chex                    1.00  0.75  44.330856
#      Q   Life                           1.00  0.67  45.328074
#      K   Corn Flakes                    1.00  1.00  45.863324
#      G   Total Whole Grain              1.00  1.00  46.658844
#      R   Wheat Chex                     1.00  0.67  49.787445
# H    Q   Quaker Oatmeal                 1.00  0.67  50.828392
# C    G   Wheaties                       1.00  1.00  51.592193
#      P   Grape Nuts Flakes              1.00  0.88  52.076897
# H    N   Cream of Wheat (Quick)         1.00  1.00  64.533816
#      A   Maypo                          1.00  1.00  54.850917
# C    K   Frosted Mini-Wheats            1.00  0.80  58.345141
#      G   Total Corn Flakes              1.00  1.00  38.839746
#          Triples                        1.00  0.75  39.106174
#          Kix                            1.00  1.50  39.241114
#          Clusters                       1.00  0.50  40.400208
#      K   Rice Krispies                  1.00  1.00  40.560159
#      R   Corn Chex                      1.00  1.00  41.445019
#      G   Cheerios                       1.00  1.25  50.764999
#      P   Grape-Nuts                     1.00  0.25  53.371007
#      K   Special K                      1.00  1.00  53.131324
#          Crispix                        1.00  1.00  46.895644
#          Just Right Crunchy  Nuggets    1.00  1.00  36.523683
#          Nutri-Grain Almond-Raisin      1.33  0.67  40.692320

# %% [markdown]
# All-Bran with Extra Fiber will be the best cereal for Sam.

# %% [markdown]
# To see the result, one should scroll down a lot. For people who only want to know the result, let's use inheritance. We will introduce logging and decorator in order to each pipe properly works. The final version of this data analysis is in the folder result.

# %% [markdown]
# ## References
#
# To study Pandas Pipe, I watched <a href="https://calmcode.io/pandas-pipe/introduction.html">pandas-pipe tutorial in calmcode</a> and <a href="https://tomaugspurger.github.io/modern-1-intro.html">modern pandas</a>.
#
# To study logging and decorators I watched <a href="https://calmcode.io/logging/introduction.html"> logging tutorial in calmcode</a> and <a href="https://calmcode.io/decorators/introduction.html ">decorator tutorial in calmcode</a>.
